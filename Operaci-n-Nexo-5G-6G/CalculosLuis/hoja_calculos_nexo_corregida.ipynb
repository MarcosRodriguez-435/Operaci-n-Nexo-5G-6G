# %% [markdown]
# # Hoja de calculos corregida
#
# Este notebook ejecuta la version corregida del script principal y regenera los CSV con los resultados consistentes del reto Operacion Nexo 5G/6G.

# %%
from pathlib import Path
import runpy

runpy.run_path(Path('hoja_calculos_nexo.py'), run_name='__main__')
