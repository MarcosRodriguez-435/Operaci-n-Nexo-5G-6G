# %% [markdown]
# # Hoja de calculos
#
# Version actualizada del cuaderno principal. Ejecuta el script corregido y regenera todos los CSV del proyecto.

# %%
from pathlib import Path
import runpy

runpy.run_path(Path('hoja_calculos_nexo.py'), run_name='__main__')
